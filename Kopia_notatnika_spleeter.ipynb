# %% [markdown]
# # Install spleeter

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
pip install spleeter

# %%
from IPython.display import Audio

# %% [markdown]
# # Separate from command line

# %%
# !wget https://promaidmusic.club/liquid.mp3
# Out:
# --2020-12-16 14:31:16--  https://promaidmusic.club/liquid.mp3
# Resolving promaidmusic.club (promaidmusic.club)... 51.83.128.199, 2001:41d0:601:1100::3472
# Connecting to promaidmusic.club (promaidmusic.club)|51.83.128.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19520171 (19M) [audio/mpeg]
# Saving to: ‘liquid.mp3.2’
#
# liquid.mp3.2        100%[===================>]  18.62M  11.2MB/s    in 1.7s
#
# 2020-12-16 14:31:17 (11.2 MB/s) - ‘liquid.mp3.2’ saved [19520171/19520171]

# %%
Audio('audio_example.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !spleeter separate -h
# Out:
# usage: spleeter separate [-h] [-a AUDIO_ADAPTER] [-p CONFIGURATION]
#                          [--verbose] -i INPUTS [INPUTS ...] [-o OUTPUT_PATH]
#                          [-f FILENAME_FORMAT] [-d DURATION] [-s OFFSET]
#                          [-c {wav,mp3,ogg,m4a,wma,flac}] [-b BITRATE] [-m]
#                          [-B {tensorflow,librosa,auto}]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a AUDIO_ADAPTER, --adapter AUDIO_ADAPTER
#                         Name of the audio adapter to use for audio I/O
#   -p CONFIGURATION, --params_filename CONFIGURATION
#                         JSON filename that contains params
#   --verbose             Shows verbose logs
#   -i INPUTS [INPUTS ...], --inputs INPUTS [INPUTS ...]
#                         List of input audio filenames
#   -o OUTPUT_PATH, --output_path OUTPUT_PATH
#                         Path of the output directory to write audio files in
# ...

# %%
# !rm output/audio_example/*

# %%
# !spleeter separate -p spleeter:4stems -i audio_example.mp3 -o output/
# Out:
# INFO:spleeter:File output/audio_example/vocals.wav written succesfully
# INFO:spleeter:File output/audio_example/drums.wav written succesfully
# INFO:spleeter:File output/audio_example/bass.wav written succesfully
# INFO:spleeter:File output/audio_example/other.wav written succesfully

# %%
# !ls output/audio_example
# Out:
# bass.wav  drums.wav  other.wav	vocals.wav

# %%
Audio('output/audio_example/other.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !ls output/audio_example
# Out:
# bass.wav  drums.wav  other.wav	vocals.wav

# %%
Audio('output/audio_example/accompaniment.wav')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-4538f2ba6283> in <module>()
# ----> 1 Audio('output/audio_example/accompaniment.wav')
#
# /usr/local/lib/python3.6/dist-packages/IPython/lib/display.py in __init__(self, data, filename, url, embed, rate, autoplay)
#      97
#      98         if self.data is not None and not isinstance(self.data, bytes):
# ---> 99             self.data = self._make_wav(data,rate)
#     100
#     101     def reload(self):
#
# /usr/local/lib/python3.6/dist-packages/IPython/lib/display.py in _make_wav(self, data, rate)
#     121             import numpy as np
#     122
# --> 123             data = np.array(data, dtype=float)
#     124             if len(data.shape) == 1:
#     125                 nchan = 1
#
# ValueError: could not convert string to float: 'output/audio_example/accompaniment.wav'
